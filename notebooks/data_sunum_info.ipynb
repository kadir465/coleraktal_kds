# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\korelaktal\data\raw_predata\colorectal_cancer_dataset.csv")
print(df1.shape)
print(df1.columns)
# Out:
# (167497, 28)
# Index(['Patient_ID', 'Country', 'Age', 'Gender', 'Cancer_Stage',
#        'Tumor_Size_mm', 'Family_History', 'Smoking_History',
#        'Alcohol_Consumption', 'Obesity_BMI', 'Diet_Risk', 'Physical_Activity',
#        'Diabetes', 'Inflammatory_Bowel_Disease', 'Genetic_Mutation',
#        'Screening_History', 'Early_Detection', 'Treatment_Type',
#        'Survival_5_years', 'Mortality', 'Healthcare_Costs',
#        'Incidence_Rate_per_100K', 'Mortality_Rate_per_100K', 'Urban_or_Rural',
#        'Economic_Classification', 'Healthcare_Access', 'Insurance_Status',
#        'Survival_Prediction'],
#       dtype='object')

# %%
df2=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\korelaktal\data\final\Merged_User_Dataset.csv")
print(df2.shape)
print(df2.columns)
# Out:
# (57531, 27)
# Index(['SEQN', 'RIDAGEYR', 'RIAGENDR', 'WHD020', 'WHD050', 'SMQ020', 'ALQ100',
#        'ALQ130', 'MCQ160C', 'MCQ160F', 'Target_Colorectal', 'Hasta_ID', 'Yas',
#        'Cinsiyet', 'Hemoglobin', 'Akyuvar_WBC', 'Kilo_Verme_Durumu',
#        'Hastalik_Durumu_LABEL', 'Sigara_Gecmisi', 'Alkol_Tuketimi',
#        'Bagirsak_Hareket_Sikligi', 'Bagirsak_Kacirma', 'Diskida_Anormallik',
#        'Kanama_Sikligi', 'Ani_Kilo_Kaybi_lbs', 'Diyabet_Gecmisi',
#        'Hipertansiyon_Gecmisi'],
#       dtype='object')

# %%
df3=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\korelaktal\data\raw_predata\2011-2012\NHANES_2011_2012_Dengelenmis_Veri.csv")
print(df3.shape)
print(df3.columns)
# Out:
# (5138, 18)
# Index(['Hasta_ID', 'Yas', 'Cinsiyet', 'Hemoglobin_Anemi', 'Akyuvar_WBC',
#        'CRP_Iltihap', 'Albumin_Beslenme', 'Ferritin_Demir', 'Sigara_Gecmisi',
#        'Alkol_Tuketimi', 'Diyabet_Gecmisi', 'Hipertansiyon_Gecmisi',
#        'Bagirsak_Hareket_Sikligi', 'Bagirsak_Kacirma', 'Diskida_Anormallik',
#        'Kanama_Sikligi', 'Ani_Kilo_Kaybi_lbs', 'Hastalik_Durumu_LABEL'],
#       dtype='object')

# %%
df4=pd.read_csv(r"C:\Users\kadir\OneDrive\Masaüstü\korelaktal\data\last_final\FINAL_LLM_EGITIM_VERISI.csv")
print(df4.shape)
print(df4["Label"].value_counts())
# Out:
# (215542, 2)
# Label
# 1    147551
# 0     67991
# Name: count, dtype: int64
