# %%
import pandas as pd

df=pd.read_csv(r'C:\Users\kadir\OneDrive\Masaüstü\korelaktal\data\final\Merged_User_Dataset.csv')
print(df.shape)
# Out:
# (57531, 27)

# %%
print(df.describe())
# Out:
#               SEQN     RIDAGEYR     RIAGENDR        WHD020        WHD050  \
# count  4523.000000  4523.000000  4523.000000   4520.000000   4520.000000
# mean   4969.805218    49.277029     1.536591   2412.281858   3286.953982
# std    2870.765140    18.952581     0.498714  14697.370164  17319.040143
# min       5.000000    20.000000     1.000000     60.000000     62.000000
# 25%    2437.000000    33.000000     1.000000    145.000000    140.000000
# 50%    4961.000000    47.000000     2.000000    168.000000    167.000000
# 75%    7452.000000    65.000000     2.000000    195.000000    195.000000
# max    9965.000000    85.000000     2.000000  99999.000000  99999.000000
#
#             SMQ020       ALQ100       ALQ130      MCQ160C      MCQ160F  ...  \
# count  4520.000000  3865.000000  2493.000000  4523.000000  4523.000000  ...
# mean      1.550221     1.343855     3.170878     2.002874     1.967057  ...
# std       0.584638     0.518802     5.528679     0.565670     0.262709  ...
# ...

# %%
print(df.isnull().sum())
print(df.columns.to_list())
# Out:
# SEQN                        53008
# RIDAGEYR                    53008
# RIAGENDR                    53008
# WHD020                      53011
# WHD050                      53011
# SMQ020                      53011
# ALQ100                      53666
# ALQ130                      55038
# MCQ160C                     53008
# MCQ160F                     53008
# Target_Colorectal           53008
# Hasta_ID                     4523
# Yas                          4523
# Cinsiyet                     4523
# Hemoglobin                  53134
# Akyuvar_WBC                 53134
# Kilo_Verme_Durumu           52571
# Hastalik_Durumu_LABEL        4523
# Sigara_Gecmisi               9498
# Alkol_Tuketimi              21727
# Bagirsak_Hareket_Sikligi    54615
# Bagirsak_Kacirma            54615
# Diskida_Anormallik          57174
# Kanama_Sikligi              57174
# Ani_Kilo_Kaybi_lbs           9845
# Diyabet_Gecmisi             19797
# Hipertansiyon_Gecmisi       19797
# dtype: int64
# ...

# %%
df.drop(columns=['SEQN', 'RIDAGEYR', 'RIAGENDR', 'WHD020', 'WHD050', 'SMQ020', 'ALQ100', 'ALQ130', 'MCQ160C', 'MCQ160F', 'Target_Colorectal',"Hemoglobin","Akyuvar_WBC","Kilo_Verme_Durumu","Bagirsak_Hareket_Sikligi"], inplace=True)
